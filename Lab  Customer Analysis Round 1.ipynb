# %%
import pandas as pd

# %%
file1=pd.read_csv("C:/Users/Jobandtalent/Desktop/Week1/Lab  Customer Analysis Round 1/Week1-Day3-Lab1/files_for_lab/csv_files/file1.csv")
file2=pd.read_csv("C:/Users/Jobandtalent/Desktop/Week1/Lab  Customer Analysis Round 1/Week1-Day3-Lab1/files_for_lab/csv_files/file2.csv")
file3=pd.read_csv("C:/Users/Jobandtalent/Desktop/Week1/Lab  Customer Analysis Round 1/Week1-Day3-Lab1/files_for_lab/csv_files/file3.csv")
display(file1)
display(file2)
display(file3)
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
display(file1.shape)
display(file2.shape)
display(file3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file1.columns=file1.columns.str.lower()

# %%
file1.columns=file1.columns.str.lower()
file2.columns=file1.columns.str.lower()
file3.columns=file1.columns.str.lower()
display(file1)
display(file2)
display(file3)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2 = file2.rename(columns={'policy type':'total claim amount', 'total claim amount': 'vehicle class','vehicle class':'policy type' })
display(file2)
file3 = file3.rename(columns={'gender':'customer lifetime value', 'total claim amount': 'vehicle class','customer lifetime value':'gender','vehicle class':'total claim amount'})
display(file3)
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
display(file2)
file2=file2.loc[:,['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
display(file2)
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
display(file3)
file3 = file3.loc[:,['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
display(file3)
# Out:
#      customer          st  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
display(file1)
display(file2)
display(file3)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2 = file2.reset_index(drop=True)

filetotal = pd.concat([file1, file2], ignore_index=True)

filetotal2 = file1.append(file2, ignore_index=True)
# Out:
# C:\Users\Jobandtalent\AppData\Local\Temp\ipykernel_4216\3243313338.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filetotal2 = file1.append(file2, ignore_index=True)

# %%
display(filetotal)
display(filetotal2)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file123 = pd.concat([file1, file2, file3], ignore_index=True)

# %%
display(file123)
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numericdata = file123.select_dtypes(include=numerics)
display(numericdata.columns)
numericdatafile1 = file1.select_dtypes(include=numerics)
print(numericdatafile1.columns)
# Out:
# Index(['income', 'monthly premium auto'], dtype='object')
# Index(['income', 'monthly premium auto', 'total claim amount'], dtype='object')

# %%
columns=file123.columns

list(set(columns)-set(numericdatafile1.columns))
# Out:
# ['gender',
#  'vehicle class',
#  'customer lifetime value',
#  'st',
#  'policy type',
#  'number of open complaints',
#  'customer',
#  'education']

# %% [markdown]
# ### Data Cleaning

# %%
file123 = file123.drop(['number of open complaints','education'], axis=1)

display(file123)
# Out:
#       customer          st gender customer lifetime value   income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
file123['customer lifetime value'] = file123['customer lifetime value'].str.rstrip("%").astype(float)/100



display(file123)
# Out:
#       customer          st gender  customer lifetime value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F                6979.5359      0.0
# 2      AI49188      Nevada      F               12887.4317  48767.0
# 3      WW63253  California      M                7645.8618      0.0
# 4      GA49547  Washington      M                5363.0765  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M                      NaN  71941.0
# 12070  PK87824  California      F                      NaN  21604.0
# 12071  TD14365  California      M                      NaN      0.0
# 12072  UP19263  California      M                      NaN  21941.0
# 12073  Y167826  California      M                      NaN      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# ...

# %%
file123= file123.drop_duplicates(subset=['customer'], keep='first')

display(file123)
# Out:
#       customer          st gender  customer lifetime value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F                6979.5359      0.0
# 2      AI49188      Nevada      F               12887.4317  48767.0
# 3      WW63253  California      M                7645.8618      0.0
# 4      GA49547  Washington      M                5363.0765  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M                      NaN  71941.0
# 12070  PK87824  California      F                      NaN  21604.0
# 12071  TD14365  California      M                      NaN      0.0
# 12072  UP19263  California      M                      NaN  21941.0
# 12073  Y167826  California      M                      NaN      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# ...

# %%
display(file123.loc[file123['income'] == 0])
# Out:
#       customer          st gender  customer lifetime value  income  \
# 0      RB50392  Washington    NaN                      NaN     0.0
# 1      QZ44356     Arizona      F                6979.5359     0.0
# 3      WW63253  California      M                7645.8618     0.0
# 7      CF85061     Arizona      M                7216.1003     0.0
# 10     SX51350  California      M                4738.9920     0.0
# ...        ...         ...    ...                      ...     ...
# 12063  WZ45103  California      F                      NaN     0.0
# 12065  RX91025  California      M                      NaN     0.0
# 12066  AC13887  California      M                      NaN     0.0
# 12071  TD14365  California      M                      NaN     0.0
# 12073  Y167826  California      M                      NaN     0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...
